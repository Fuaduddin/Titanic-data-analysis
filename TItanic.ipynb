# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
# %matplotlib inline

# %%
dt= pd.read_csv(r"E:\GOOGLE DIGITAL GARAGE\DATA ANALYSIS\DATASET\train.csv")

# %%
dt.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
dt.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
dt.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
sns.countplot('Sex',data=dt)

# %%
dt['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
sns.countplot('Sex',data=dt,hue='Survived')

# %%
dt['Sex'].value_counts().plot(kind='pie',figsize=(8,5),shadow=True)
plt.legend(title = "Survived:",loc='center left',bbox_to_anchor=(1, 0, 0.5, 1),shadow=True)

# %%
sns.countplot('Pclass',data=dt)

# %%
sns.countplot('Pclass',data=dt,hue='Sex')

# %%
sns.countplot('Pclass',data=dt,hue='Survived')

# %%
dt['Pclass'].value_counts().plot(kind='pie',figsize=(8,5),shadow=True)
plt.legend(title = "Survived:Sex",loc='center left',bbox_to_anchor=(1, 0, 0.5, 1),shadow=True)

# %%
sns.countplot('SibSp',data=dt)

# %%
sns.countplot('SibSp',data=dt, hue='Survived')

# %%
dt['Sex'].value_counts().plot(kind='pie',figsize=(8,5),shadow=True)
plt.legend(title = "Survived:SipSp",loc='center left',bbox_to_anchor=(1, 0, 0.5, 1),shadow=True)

# %%
sns.countplot('Cabin',data=dt)

# %%
sns.countplot('Cabin',data=dt, hue='Survived')

# %%
sns.Implot('Age','Survived',data=dt)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-2174a74128fe> in <module>
# ----> 1 sns.Implot('Age','Survived',data=dt)
#
# AttributeError: module 'seaborn' has no attribute 'Implot'

# %%
sns.lmplot('Age','Survived',data=dt)

# %%
sns.lmplot('Age','Survived',data=dt, hue='Pclass' )

# %%
sns.countplot('Embarked',data=dt,hue='Survived')
